# %%
# Importing packages
import matplotlib.pyplot as plt

# %%
time_period = ["7 days", "14 days", "31 days"]
query3 = [5.4, 13.3, 11.6]
query4 = [49.3, 102.4, 262.0]
query5 = [53.5, 105.2, 325.5]
query6 = [12.3, 13.7, 16.3]
query7 = [5.5, 6.4, 8.9]
query8 = [0.3, 2.1, 4.6]
query9 = [32.6, 61.4, 134.4]

# %%
# Plot a simple line chart
plt.plot(time_period, query3)
plt.plot(time_period, query4)
plt.plot(time_period, query5)
plt.plot(time_period, query6)
plt.plot(time_period, query7)
plt.plot(time_period, query8)
plt.plot(time_period, query9)
plt.legend(['query3', 'query4', 'query5', 'query6', 'query7', 'query8', 'query9'])
